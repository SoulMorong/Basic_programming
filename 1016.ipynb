# %% [markdown]
# <a href="https://colab.research.google.com/github/SoulMorong/Basic_programming/blob/main/1016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np
"""for r in range(10):
  com_num = random.randint(1,5)
  user_num = int(input("숫자를 입력하세요 : "))
  if (com_num == user_num):
    print("정답입니다!")
    break
  else:
    print(f"오답입니다. {com_num} 이였어요!\n남은 횟수 : {9-r}\n")"""

"""init_num = random.randint(0,100)
count = 0
while True:
  user_num = int(input("숫자를 입력하세요 : "))
  count += 1
  if (init_num < user_num):
    print("업")
  elif (init_num > user_num):
    print("다운")
  else:
    print(f"축하합니다, 정답입니다.\n시행 횟수 : {count}")
    break"""

"""while True:
  num_1 = random.randint(0,100)
  num_2 = random.randint(0,100)

  user_ans = int(input(f"{num_1} + {num_2} = "))
  if(user_ans == sum([num_1,num_2])):
    print("정답입니다!")
  else:
    print(f"오답입니다,정답 : {sum([num_1,num_2])}")"""

"""lista = [10,30,20]
lista[::] #전체 슬라이싱"""

"""def sum_v(input):
  cache = 0
  for r in input:
    cache += r
  return cache

def mean(input_list):
  return sum_v(input_list)/len(input_list)

score = []
for r in range(5):
  score.append(int(input("점수를 입력하세요 : ")))
print(f"평균 점수는 {np.mean(score)}점 입니다.")
print(mean(score))"""

"""#tuple
num = 1,2,3 #tuple
print(num)
num = (1,2,3)
print(num)"""

"""
tuple : 수정 불가 (append 불가)
del(tuple) : 튜플 삭제
튜플 수정하고 싶을때는 list로 바꾼 후 수정하는 편법 존재
list(tuple)
"""

# dict = {"key":"value"}

"""for r in dict.keys():
  print(r, dict.keys())"""
"""
singer = {}
singer['이름'] = input("그룹 이름 : ")
singer['구성원수'] = int(input("그룹 구성원 : "))
singer['대뷔 프로그램'] = input("대뷔 프로그램 :")
singer['대표곡'] = input("대표곡 : ")

for r in singer.keys():
  print(f"{r} ==> {singer[r]}")"""

store = {}

while True:
  item = input("입력 물품 : ")
  if (item == "중지"):
    break
  else:
    amount = input("재고량 : ")
    store[item] = amount
print("\n** 물품의 재고량 확인 **")
while True:
  try:
    find_stuff = input("찾을 물품 : ")
    if (find_stuff == "중지"):
      break
    find_amount = store[find_stuff]
    print(find_amount)
  except Exception as e:
    print("그건 없어요")
print("\n** 프로그램 종료 **")
# Out:
# 입력 물품 : 삼김
# 재고량 : 12
# 입력 물품 : 콜라
# 재고량 : 239
# 입력 물품 : 중지
# 물품의 재고량 확인
# 찾을 물품 : 삼김
# 12
# 찾을 물품 : 콜라
# 239
# 찾을 물품 : 도시락
# 그건 없어요
# 찾을 물품 : 중지
