# %% [markdown]
# <a href="https://colab.research.google.com/github/SoulMorong/Basic_programming/blob/main/1023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
"""def main():
  operator = input("연산자를 입력하세요 : ")
  operator_list = ["*","-","+","/"]
  if (operator not in operator_list):
    return "올바른 연산자를 입력하세요"
  else:
    a = int(input("숫자 1을 입력하세요 : "))
    b = int(input("숫자 2를 입력하세요 : "))
    if (operator == "*"):
      return f"{a} {operator} {b} = {a*b}"
    elif (operator == "-"):
      return f"{a} {operator} {b} = {a-b}"
    elif (operator == "+"):
      return f"{a} {operator} {b} = {a+b}"
    elif (operator == "/"):
      return f"{a} {operator} {b} = {a/b}"
    """
"""def main():
  num_list = []
  for r in range(6):
    while (True):
      selnum = random.randint(1,45)
      if (selnum not in num_list):
        num_list.append(selnum)
        break
  num_list.sort()
  return num_list
if (__name__ == "__main__"):
  print(main())"""

"""import datetime as d
print(d.datetime.now(tz=d.timezone(d.timedelta(hours=+9))))"""

password = input("새로운 비밀번호를 입력하세요 : ")
if (len(password) <8):
  print("규칙에 맞지 않습니다.")
if (password.isalnum == False)
# Out:
# 2024-10-23 12:19:40.299728+09:00
